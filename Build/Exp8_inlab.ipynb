# %% [markdown]
# # Experiment 8: Artificial Neural Networks using Keras

# %% [markdown]
# ## Task 1: Design and implement Artificial Neural Network architectures using Keras for classification tasks
# *Suggested Dataset: Pima Indians Diabetes Dataset*

# %% [markdown]
# ### Subtask 1.1: Data Acquisition, Imputation, and Feature Scaling
# **Concept:** Import warnings suppression, load the raw Pima Indians dataset, handle missing value zeros using median imputation, standardize the features, and perform a stratified train-test split.

# %%
import warnings

# %%
warnings.filterwarnings("ignore")

# %%
import numpy as np

# %%
import pandas as pd

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.impute import SimpleImputer

# %%
# Load Pima Indians Diabetes dataset
pima_url = "https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.data.csv"

# %%
pima_cols = ['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome']

# %%
pima_df = pd.read_csv(pima_url, header=None, names=pima_cols)

# %%
# Prevent copy warnings using an explicit copy
X_pima = pima_df[pima_cols[:-1]].copy()

# %%
y_pima = pima_df['Outcome']

# %%
# Mark invalid zeros as NaN placeholders for imputation
cols_to_impute = ['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI']

# %%
X_pima[cols_to_impute] = X_pima[cols_to_impute].replace(0, np.nan)

# %%
# Impute and standardize
imputer = SimpleImputer(strategy='median')

# %%
X_imputed = imputer.fit_transform(X_pima)

# %%
scaler = StandardScaler()

# %%
X_pima_scaled = scaler.fit_transform(X_imputed)

# %%
# Stratified train-test split
X_train_p, X_test_p, y_train_p, y_test_p = train_test_split(
    X_pima_scaled, y_pima, test_size=0.20, stratify=y_pima, random_state=42
)

# %%
print("Preprocessed Pima dataset shapes:")
print(f"  Training set features: {X_train_p.shape} | Test set features: {X_test_p.shape}")
# Out:
# Preprocessed Pima dataset shapes:
#   Training set features: (614, 8) | Test set features: (154, 8)

# %% [markdown]
# ### Subtask 1.2: Designing Feedforward Neural Network Architectures
# **Concept:** Design a baseline feedforward Artificial Neural Network (ANN) using Keras Sequential API, configuring hidden Dense layers with ReLU activations and a binary Sigmoid output node.

# %%
import tensorflow as tf

# %%
from tensorflow.keras.models import Sequential

# %%
from tensorflow.keras.layers import Dense

# %%
# Design baseline sequential model
ann_pima = Sequential([
    # Input layer + Hidden layer 1: 16 neurons with ReLU activation
    Dense(16, activation='relu', input_shape=(8,)),
    # Hidden layer 2: 8 neurons with ReLU activation
    Dense(8, activation='relu'),
    # Output layer: 1 neuron with Sigmoid activation for binary classification
    Dense(1, activation='sigmoid')
])

# %%
print("Sequential ANN Architecture established:")
ann_pima.summary()
# Out:
# Sequential ANN Architecture established:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 16)             │           144 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 8)              │           136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 289 (1.13 KB)
#  Trainable params: 289 (1.13 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Subtask 1.3: Compiling the Neural Network Model
# **Concept:** Compile the sequential model by defining binary_crossentropy as the loss function, Adam as the optimizer, and accuracy as the primary evaluation metric.

# %%
# Compile the neural network model
ann_pima.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# %%
print("Neural network model compiled successfully.")
# Out:
# Neural network model compiled successfully.

# %% [markdown]
# ### Subtask 1.4: Fitting the Network with Validation Splits
# **Concept:** Train the compiled network on the training set for 50 epochs using a batch size of 16 and a 20% validation split.

# %%
# Fit model and collect training metrics
history_pima = ann_pima.fit(
    X_train_p,
    y_train_p,
    epochs=50,
    batch_size=16,
    validation_split=0.2,
    verbose=1
)
# Out:
# Epoch 1/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.6802 - loss: 0.5891 - val_accuracy: 0.6748 - val_loss: 0.5643
# Epoch 2/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6925 - loss: 0.5523 - val_accuracy: 0.6992 - val_loss: 0.5422
# Epoch 3/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7108 - loss: 0.5284 - val_accuracy: 0.7154 - val_loss: 0.5276
# Epoch 4/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7454 - loss: 0.5095 - val_accuracy: 0.7480 - val_loss: 0.5161
# Epoch 5/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.7413 - loss: 0.4953 - val_accuracy: 0.7398 - val_loss: 0.5024
# Epoch 6/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.7495 - loss: 0.4839 - val_accuracy: 0.7480 - val_loss: 0.4930
# Epoch 7/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.7556 - loss: 0.4753 - val_accuracy: 0.7642 - val_loss: 0.4856
# Epoch 8/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7637 - loss: 0.4675 - val_accuracy: 0.7561 - val_loss: 0.4790
# Epoch 9/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.7739 - loss: 0.4617 - val_accuracy: 0.7642 - val_loss: 0.4744
# Epoch 10/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.7719 - loss: 0.4568 - val_accuracy: 0.7724 - val_loss: 0.4685
# Epoch 11/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7760 - loss: 0.4535 - val_accuracy: 0.7642 - val_loss: 0.4640
# Epoch 12/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7739 - loss: 0.4493 - val_accuracy: 0.7805 - val_loss: 0.4599
# Epoch 13/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7800 - loss: 0.4453 - val_accuracy: 0.7967 - val_loss: 0.4556
# Epoch 14/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7780 - loss: 0.4430 - val_accuracy: 0.7967 - val_loss: 0.4528
# Epoch 15/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7821 - loss: 0.4396 - val_accuracy: 0.8049 - val_loss: 0.4513
# Epoch 16/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7841 - loss: 0.4368 - val_accuracy: 0.8049 - val_loss: 0.4461
# Epoch 17/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7841 - loss: 0.4343 - val_accuracy: 0.7967 - val_loss: 0.4453
# Epoch 18/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7882 - loss: 0.4331 - val_accuracy: 0.8130 - val_loss: 0.4427
# Epoch 19/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7902 - loss: 0.4315 - val_accuracy: 0.8130 - val_loss: 0.4420
# Epoch 20/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7923 - loss: 0.4292 - val_accuracy: 0.8211 - val_loss: 0.4394
# Epoch 21/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7943 - loss: 0.4282 - val_accuracy: 0.8130 - val_loss: 0.4400
# Epoch 22/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7902 - loss: 0.4255 - val_accuracy: 0.8211 - val_loss: 0.4364
# Epoch 23/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7923 - loss: 0.4246 - val_accuracy: 0.8130 - val_loss: 0.4365
# Epoch 24/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7923 - loss: 0.4234 - val_accuracy: 0.8211 - val_loss: 0.4347
# Epoch 25/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7943 - loss: 0.4222 - val_accuracy: 0.8293 - val_loss: 0.4347
# Epoch 26/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7963 - loss: 0.4217 - val_accuracy: 0.8211 - val_loss: 0.4330
# Epoch 27/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7923 - loss: 0.4195 - val_accuracy: 0.8211 - val_loss: 0.4335
# Epoch 28/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8004 - loss: 0.4187 - val_accuracy: 0.8211 - val_loss: 0.4347
# Epoch 29/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8024 - loss: 0.4176 - val_accuracy: 0.8211 - val_loss: 0.4317
# Epoch 30/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8045 - loss: 0.4166 - val_accuracy: 0.8211 - val_loss: 0.4331
# Epoch 31/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8024 - loss: 0.4154 - val_accuracy: 0.8130 - val_loss: 0.4329
# Epoch 32/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8065 - loss: 0.4144 - val_accuracy: 0.8130 - val_loss: 0.4362
# Epoch 33/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8086 - loss: 0.4134 - val_accuracy: 0.8130 - val_loss: 0.4323
# Epoch 34/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8126 - loss: 0.4112 - val_accuracy: 0.8130 - val_loss: 0.4339
# Epoch 35/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8167 - loss: 0.4104 - val_accuracy: 0.7967 - val_loss: 0.4340
# Epoch 36/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8147 - loss: 0.4093 - val_accuracy: 0.7967 - val_loss: 0.4363
# Epoch 37/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8126 - loss: 0.4081 - val_accuracy: 0.7967 - val_loss: 0.4342
# Epoch 38/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8147 - loss: 0.4070 - val_accuracy: 0.7967 - val_loss: 0.4356
# Epoch 39/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8126 - loss: 0.4064 - val_accuracy: 0.7967 - val_loss: 0.4368
# Epoch 40/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8126 - loss: 0.4041 - val_accuracy: 0.8049 - val_loss: 0.4369
# Epoch 41/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8147 - loss: 0.4036 - val_accuracy: 0.8049 - val_loss: 0.4375
# Epoch 42/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8147 - loss: 0.4024 - val_accuracy: 0.8049 - val_loss: 0.4371
# Epoch 43/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8147 - loss: 0.4019 - val_accuracy: 0.7967 - val_loss: 0.4387
# Epoch 44/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8126 - loss: 0.4006 - val_accuracy: 0.7967 - val_loss: 0.4415
# Epoch 45/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8248 - loss: 0.4010 - val_accuracy: 0.7967 - val_loss: 0.4415
# Epoch 46/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8208 - loss: 0.3984 - val_accuracy: 0.7967 - val_loss: 0.4403
# Epoch 47/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8248 - loss: 0.3987 - val_accuracy: 0.7967 - val_loss: 0.4408
# Epoch 48/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8228 - loss: 0.3966 - val_accuracy: 0.7967 - val_loss: 0.4446
# Epoch 49/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8187 - loss: 0.3954 - val_accuracy: 0.7967 - val_loss: 0.4416
# Epoch 50/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8248 - loss: 0.3943 - val_accuracy: 0.7967 - val_loss: 0.4447

# %%
print("\nModel training complete.")
# Out:
# Model training complete.

# %% [markdown]
# ### Subtask 1.5: Evaluating Classifications on Held-out Test Data
# **Concept:** Predict output probabilities on held-out test data, threshold them at 0.5, and evaluate predictions using accuracy, a confusion matrix, and a classification report.

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
# Predict target probabilities
y_pred_probs = ann_pima.predict(X_test_p)
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step

# %%
# Threshold probabilities to binary classes (0 or 1)
y_pred_classes = (y_pred_probs >= 0.5).astype(int)

# %%
test_acc = accuracy_score(y_test_p, y_pred_classes)

# %%
print(f"ANN Holdout Test Accuracy: {test_acc * 100:.2f}%\n")

print("--- Classification Report ---")
print(classification_report(y_test_p, y_pred_classes, target_names=['No Diabetes', 'Diabetes']))
# Out:
# ANN Holdout Test Accuracy: 73.38%
#
# --- Classification Report ---
#               precision    recall  f1-score   support
#
#  No Diabetes       0.79      0.81      0.80       100
#     Diabetes       0.63      0.59      0.61        54
#
#     accuracy                           0.73       154
#    macro avg       0.71      0.70      0.70       154
# weighted avg       0.73      0.73      0.73       154

# %%
# Plot confusion matrix
cm_pima = confusion_matrix(y_test_p, y_pred_classes)
plt.figure(figsize=(5, 4))
sns.heatmap(cm_pima, annot=True, fmt='d', cmap='Blues', xticklabels=['No Diabetes', 'Diabetes'], yticklabels=['No Diabetes', 'Diabetes'])
plt.title("ANN Classification Confusion Matrix - 24EU02061")
plt.show()

# %% [markdown]
# ## Task 2: Train neural network models and analyze learning behavior using suitable evaluation measures
# *Suggested Dataset: Sonar Dataset*

# %% [markdown]
# ### Subtask 2.1: Standard Scaling and High-Dimensional Data Splitting
# **Concept:** Import warnings suppression, load the Sonar dataset, map nominal class labels, standardize features, and perform a stratified split.

# %%
import warnings

# %%
warnings.filterwarnings("ignore")

# %%
import pandas as pd

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.preprocessing import StandardScaler

# %%
# Load Sonar dataset
sonar_url = "https://raw.githubusercontent.com/jbrownlee/Datasets/master/sonar.csv"

# %%
sonar_features = [f"F_{i}" for i in range(1, 61)]

# %%
sonar_columns = sonar_features + ['Class']

# %%
sonar_df = pd.read_csv(sonar_url, header=None, names=sonar_columns)

# %%
# Encode class: M -> 1, R -> 0
sonar_df['Class_numeric'] = sonar_df['Class'].map({'M': 1, 'R': 0})

# %%
X_sonar = sonar_df[sonar_features]
y_sonar = sonar_df['Class_numeric']

# %%
# Scale features
scaler_sonar = StandardScaler()
X_sonar_scaled = scaler_sonar.fit_transform(X_sonar)

# %%
# Split into train/test sets
X_train_s, X_test_s, y_train_s, y_test_s = train_test_split(
    X_sonar_scaled, y_sonar, test_size=0.30, stratify=y_sonar, random_state=42
)

# %%
print("Sonar Training Set Shape:", X_train_s.shape)
print("Sonar Test Set Shape:", X_test_s.shape)
# Out:
# Sonar Training Set Shape: (145, 60)
# Sonar Test Set Shape: (63, 60)

# %% [markdown]
# ### Subtask 2.2: Designing Deep Neural Networks with Dropout Regularization
# **Concept:** Construct a deep multi-layer neural network using Keras and incorporate Dropout layers to prevent overfitting on high-dimensional continuous features.

# %%
from tensorflow.keras.models import Sequential

# %%
from tensorflow.keras.layers import Dense, Dropout

# %%
# Design regularized sequential network
ann_sonar = Sequential([
    # Input layer + Dense hidden layer 1
    Dense(64, activation='relu', input_shape=(60,)),
    Dropout(0.3), # Apply 30% dropout rate to mitigate co-adaptation
    # Dense hidden layer 2
    Dense(32, activation='relu'),
    Dropout(0.3), # Apply 30% dropout rate
    # Binary sigmoid output node
    Dense(1, activation='sigmoid')
])

# %%
print("Regularized Sonar ANN Architecture established:")
ann_sonar.summary()
# Out:
# Regularized Sonar ANN Architecture established:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_3 (Dense)                 │ (None, 64)             │         3,904 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 6,017 (23.50 KB)
#  Trainable params: 6,017 (23.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Subtask 2.3: Compiling and Training the Sonar Network
# **Concept:** Compile your model with the Adam optimizer, fit it on the Sonar training set for 80 epochs, and collect the training metrics.

# %%
# Compile the model
ann_sonar.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# %%
# Fit model and collect training metrics
history_sonar = ann_sonar.fit(
    X_train_s,
    y_train_s,
    epochs=80,
    batch_size=16,
    validation_split=0.2,
    verbose=1
)
# Out:
# Epoch 1/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.5172 - loss: 0.7794 - val_accuracy: 0.6552 - val_loss: 0.6856
# Epoch 2/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5948 - loss: 0.7212 - val_accuracy: 0.7241 - val_loss: 0.6371
# Epoch 3/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6638 - loss: 0.6198 - val_accuracy: 0.7931 - val_loss: 0.5981
# Epoch 4/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7241 - loss: 0.5998 - val_accuracy: 0.7586 - val_loss: 0.5716
# Epoch 5/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7586 - loss: 0.5642 - val_accuracy: 0.7586 - val_loss: 0.5541
# Epoch 6/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7845 - loss: 0.5227 - val_accuracy: 0.7586 - val_loss: 0.5371
# Epoch 7/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7931 - loss: 0.5013 - val_accuracy: 0.7586 - val_loss: 0.5195
# Epoch 8/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7586 - loss: 0.5048 - val_accuracy: 0.7586 - val_loss: 0.5112
# Epoch 9/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8017 - loss: 0.4617 - val_accuracy: 0.7586 - val_loss: 0.5047
# Epoch 10/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8190 - loss: 0.4348 - val_accuracy: 0.7586 - val_loss: 0.4918
# Epoch 11/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8793 - loss: 0.3972 - val_accuracy: 0.7586 - val_loss: 0.4764
# Epoch 12/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7759 - loss: 0.4594 - val_accuracy: 0.7931 - val_loss: 0.4617
# Epoch 13/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8190 - loss: 0.4254 - val_accuracy: 0.7931 - val_loss: 0.4522
# Epoch 14/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8707 - loss: 0.3600 - val_accuracy: 0.7931 - val_loss: 0.4422
# Epoch 15/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8276 - loss: 0.3735 - val_accuracy: 0.7931 - val_loss: 0.4313
# Epoch 16/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8621 - loss: 0.3440 - val_accuracy: 0.7931 - val_loss: 0.4216
# Epoch 17/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8621 - loss: 0.3313 - val_accuracy: 0.7931 - val_loss: 0.4125
# Epoch 18/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9052 - loss: 0.2787 - val_accuracy: 0.7931 - val_loss: 0.4069
# Epoch 19/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8879 - loss: 0.2927 - val_accuracy: 0.7931 - val_loss: 0.4011
# Epoch 20/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9052 - loss: 0.2764 - val_accuracy: 0.7931 - val_loss: 0.3918
# Epoch 21/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9138 - loss: 0.2657 - val_accuracy: 0.7931 - val_loss: 0.3902
# Epoch 22/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9310 - loss: 0.2451 - val_accuracy: 0.7931 - val_loss: 0.3920
# Epoch 23/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9138 - loss: 0.2233 - val_accuracy: 0.7931 - val_loss: 0.3900
# Epoch 24/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9138 - loss: 0.2577 - val_accuracy: 0.7931 - val_loss: 0.3914
# Epoch 25/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9138 - loss: 0.2337 - val_accuracy: 0.8276 - val_loss: 0.3851
# Epoch 26/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9397 - loss: 0.2049 - val_accuracy: 0.8276 - val_loss: 0.3860
# Epoch 27/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9052 - loss: 0.2264 - val_accuracy: 0.8276 - val_loss: 0.3805
# Epoch 28/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9397 - loss: 0.1853 - val_accuracy: 0.7931 - val_loss: 0.3775
# Epoch 29/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9224 - loss: 0.1906 - val_accuracy: 0.7931 - val_loss: 0.3777
# Epoch 30/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9310 - loss: 0.1837 - val_accuracy: 0.7931 - val_loss: 0.3730
# Epoch 31/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9310 - loss: 0.2113 - val_accuracy: 0.7931 - val_loss: 0.3714
# Epoch 32/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9397 - loss: 0.1615 - val_accuracy: 0.7931 - val_loss: 0.3810
# Epoch 33/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9483 - loss: 0.1658 - val_accuracy: 0.7931 - val_loss: 0.3863
# Epoch 34/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9224 - loss: 0.1896 - val_accuracy: 0.7931 - val_loss: 0.3881
# Epoch 35/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9483 - loss: 0.1480 - val_accuracy: 0.7931 - val_loss: 0.3870
# Epoch 36/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9397 - loss: 0.1794 - val_accuracy: 0.8276 - val_loss: 0.3739
# Epoch 37/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9914 - loss: 0.1043 - val_accuracy: 0.8276 - val_loss: 0.3681
# Epoch 38/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9569 - loss: 0.1430 - val_accuracy: 0.8276 - val_loss: 0.3751
# Epoch 39/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9569 - loss: 0.1424 - val_accuracy: 0.8276 - val_loss: 0.3936
# Epoch 40/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9569 - loss: 0.1249 - val_accuracy: 0.8276 - val_loss: 0.3998
# Epoch 41/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9655 - loss: 0.1223 - val_accuracy: 0.8276 - val_loss: 0.4028
# Epoch 42/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9569 - loss: 0.1236 - val_accuracy: 0.8276 - val_loss: 0.4051
# Epoch 43/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9655 - loss: 0.1073 - val_accuracy: 0.8276 - val_loss: 0.4022
# Epoch 44/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9655 - loss: 0.1227 - val_accuracy: 0.8276 - val_loss: 0.4087
# Epoch 45/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9828 - loss: 0.0819 - val_accuracy: 0.8276 - val_loss: 0.4125
# Epoch 46/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9828 - loss: 0.1023 - val_accuracy: 0.8276 - val_loss: 0.4194
# Epoch 47/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9828 - loss: 0.0913 - val_accuracy: 0.8276 - val_loss: 0.4228
# Epoch 48/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9569 - loss: 0.0931 - val_accuracy: 0.8276 - val_loss: 0.4169
# Epoch 49/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0738 - val_accuracy: 0.8276 - val_loss: 0.4231
# Epoch 50/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9655 - loss: 0.1070 - val_accuracy: 0.8276 - val_loss: 0.4331
# Epoch 51/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9914 - loss: 0.0712 - val_accuracy: 0.8276 - val_loss: 0.4422
# Epoch 52/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9569 - loss: 0.0815 - val_accuracy: 0.8276 - val_loss: 0.4584
# Epoch 53/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9914 - loss: 0.0515 - val_accuracy: 0.8276 - val_loss: 0.4763
# Epoch 54/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0491 - val_accuracy: 0.8276 - val_loss: 0.4896
# Epoch 55/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9914 - loss: 0.0532 - val_accuracy: 0.8276 - val_loss: 0.4919
# Epoch 56/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9828 - loss: 0.0474 - val_accuracy: 0.8276 - val_loss: 0.4825
# Epoch 57/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9828 - loss: 0.0663 - val_accuracy: 0.8276 - val_loss: 0.4825
# Epoch 58/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0467 - val_accuracy: 0.8276 - val_loss: 0.4850
# Epoch 59/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0288 - val_accuracy: 0.8276 - val_loss: 0.4854
# Epoch 60/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9828 - loss: 0.0625 - val_accuracy: 0.8276 - val_loss: 0.4862
# Epoch 61/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9828 - loss: 0.0541 - val_accuracy: 0.8276 - val_loss: 0.4928
# Epoch 62/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0517 - val_accuracy: 0.8276 - val_loss: 0.4973
# Epoch 63/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9914 - loss: 0.0463 - val_accuracy: 0.8276 - val_loss: 0.4911
# Epoch 64/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9914 - loss: 0.0443 - val_accuracy: 0.8276 - val_loss: 0.4976
# Epoch 65/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9828 - loss: 0.0595 - val_accuracy: 0.8276 - val_loss: 0.5113
# Epoch 66/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9828 - loss: 0.0531 - val_accuracy: 0.8276 - val_loss: 0.5203
# Epoch 67/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9741 - loss: 0.0702 - val_accuracy: 0.8276 - val_loss: 0.5103
# Epoch 68/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9914 - loss: 0.0355 - val_accuracy: 0.8276 - val_loss: 0.5083
# Epoch 69/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9914 - loss: 0.0350 - val_accuracy: 0.8276 - val_loss: 0.5141
# Epoch 70/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9828 - loss: 0.0458 - val_accuracy: 0.8276 - val_loss: 0.5386
# Epoch 71/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9914 - loss: 0.0335 - val_accuracy: 0.8276 - val_loss: 0.5519
# Epoch 72/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9741 - loss: 0.0750 - val_accuracy: 0.8276 - val_loss: 0.5701
# Epoch 73/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0237 - val_accuracy: 0.8276 - val_loss: 0.5801
# Epoch 74/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9914 - loss: 0.0311 - val_accuracy: 0.8276 - val_loss: 0.5885
# Epoch 75/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9914 - loss: 0.0286 - val_accuracy: 0.8276 - val_loss: 0.5924
# Epoch 76/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9828 - loss: 0.0380 - val_accuracy: 0.8276 - val_loss: 0.6022
# Epoch 77/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0217 - val_accuracy: 0.7931 - val_loss: 0.6068
# Epoch 78/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0228 - val_accuracy: 0.7931 - val_loss: 0.6086
# Epoch 79/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9914 - loss: 0.0340 - val_accuracy: 0.8276 - val_loss: 0.6111
# Epoch 80/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0321 - val_accuracy: 0.8276 - val_loss: 0.6131

# %%
print("\nModel training complete.")
# Out:
# Model training complete.

# %% [markdown]
# ### Subtask 2.4: Plotting Loss and Accuracy Learning Curves
# **Concept:** Plot the training versus validation loss and training versus validation accuracy curves across epochs to analyze model convergence and detect overfitting.

# %%
import matplotlib.pyplot as plt

# %%
# Extract metrics from training history
train_loss = history_sonar.history['loss']
val_loss = history_sonar.history['val_loss']
train_acc = history_sonar.history['accuracy']
val_acc = history_sonar.history['val_accuracy']
epochs_range = range(1, len(train_loss) + 1)

# Plot loss curves
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

axes[0].plot(epochs_range, train_loss, 'b-', label='Training Loss')
axes[0].plot(epochs_range, val_loss, 'r-', label='Validation Loss')
axes[0].set_title("24EU02016-Training vs. Validation Loss - 24EU02061")
axes[0].set_xlabel("Epochs")
axes[0].set_ylabel("Loss")
axes[0].legend()

# Plot accuracy curves
axes[1].plot(epochs_range, train_acc, 'b-', label='Training Accuracy')
axes[1].plot(epochs_range, val_acc, 'r-', label='Validation Accuracy')
axes[1].set_title("24EU02016-Training vs. Validation Accuracy - 24EU02061")
axes[1].set_xlabel("Epochs")
axes[1].set_ylabel("Accuracy")
axes[1].legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Subtask 2.5: Evaluating Classification Metrics and ROC-AUC Curves
# **Concept:** Evaluate predictions on the test set and plot the Receiver Operating Characteristic (ROC) curve to calculate the Area Under the Curve (AUC).

# %%
from sklearn.metrics import classification_report, roc_curve, auc

# %%
import matplotlib.pyplot as plt

# %%
# Predict probabilities on test set
sonar_probs = ann_sonar.predict(X_test_s)[:, 0]
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step

# %%
sonar_preds = (sonar_probs >= 0.5).astype(int)

# %%
# Print classification report
print("--- Classification Report (Sonar Test Set) ---")
print(classification_report(y_test_s, sonar_preds, target_names=['Rock (0)', 'Mine (1)']))
# Out:
# --- Classification Report (Sonar Test Set) ---
#               precision    recall  f1-score   support
#
#     Rock (0)       0.84      0.93      0.89        29
#     Mine (1)       0.94      0.85      0.89        34
#
#     accuracy                           0.89        63
#    macro avg       0.89      0.89      0.89        63
# weighted avg       0.89      0.89      0.89        63

# %%
# Compute ROC curve coordinates and AUC score
fpr, tpr, _ = roc_curve(y_test_s, sonar_probs)
roc_auc = auc(fpr, tpr)

# %%
# Plot the ROC curve
plt.figure(figsize=(6, 4.5))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC Curve (AUC = {roc_auc:.4f})')
plt.plot([0, 1], [0, 1], color='navy', lw=1.5, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.title("24EU02016-ROC Curve: Sonar Classification - 24EU02061")
plt.xlabel("False Positive Rate (1 - Specificity)")
plt.ylabel("True Positive Rate (Sensitivity)")
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# ## Task 3: Perform hyperparameter optimization to improve neural network performance and generalization
# *Continuous Optimization and Regularization on Pima Indians Dataset*

# %% [markdown]
# ### Subtask 3.1: Building a Parameterized Network Builder Function
# **Concept:** Construct a flexible, parameter-driven builder function that lets you compile an ANN model with different optimizer choices.

# %%
import tensorflow as tf

# %%
from tensorflow.keras.models import Sequential

# %%
from tensorflow.keras.layers import Dense

# %%
# Define parameterized builder function
def build_ann_model(optimizer_name='adam'):
    model = Sequential([
        Dense(32, activation='relu', input_shape=(8,)),
        Dense(16, activation='relu'),
        Dense(1, activation='sigmoid')
    ])
    model.compile(
        optimizer=optimizer_name,
        loss='binary_crossentropy',
        metrics=['accuracy']
    )
    return model

# %%
print("Modular ANN model builder function established.")
# Out:
# Modular ANN model builder function established.

# %% [markdown]
# ### Subtask 3.2: Tuning Convergence Speeds manually
# **Concept:** Run a manual search loop across different optimizers (Adam, SGD, RMSprop) to compare training loss convergence.

# %%
optimizers = ['adam', 'sgd', 'rmsprop']
history_records = {}

# %%
print("--- Running Optimizer Search ---")
for opt in optimizers:
    print(f"Training network using: {opt}...")
    temp_model = build_ann_model(optimizer_name=opt)

    # Fit for 30 epochs
    hist = temp_model.fit(
        X_train_p,
        y_train_p,
        validation_split=0.2,
        epochs=30,
        batch_size=16,
        verbose=0
    )
    history_records[opt] = hist.history['loss']
# Out:
# --- Running Optimizer Search ---
# Training network using: adam...
# Training network using: sgd...
# Training network using: rmsprop...

# %%
print("Tuning loop complete.")
# Out:
# Tuning loop complete.

# %% [markdown]
# ### Subtask 3.3: Comparing Optimizer Loss Trajectories
# **Concept:** Plot the training loss trajectories across your selected optimizers to evaluate and select the fastest converging solver.

# %%
import matplotlib.pyplot as plt

# %%
# Plot optimizer training loss profiles
plt.figure(figsize=(7, 4.5))
for opt in optimizers:
    plt.plot(range(1, 31), history_records[opt], label=f"Optimizer: {opt.upper()}")

plt.title("24EU02016-Training Loss Convergence Comparison - 24EU02061")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %% [markdown]
# ### Subtask 3.4: Implementing Early Stopping Regularization
# **Concept:** Set up an EarlyStopping callback to automatically halt training and restore the best weights when the validation loss stops improving.

# %%
from tensorflow.keras.callbacks import EarlyStopping

# %%
# Configure EarlyStopping callback
early_stop = EarlyStopping(
    monitor='val_loss',
    patience=10,
    restore_best_weights=True,
    verbose=1
)

# %%
# Build model with the optimal optimizer found
tuned_model = build_ann_model(optimizer_name='adam')

# %%
print("Training model with Early Stopping...")
# Out:
# Training model with Early Stopping...

# %%
# Fit model for up to 100 epochs
history_tuned = tuned_model.fit(
    X_train_p,
    y_train_p,
    validation_split=0.2,
    epochs=100,
    batch_size=16,
    callbacks=[early_stop],
    verbose=1
)
# Out:
# Epoch 1/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.3809 - loss: 0.8271 - val_accuracy: 0.5041 - val_loss: 0.6952
# Epoch 2/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5906 - loss: 0.6929 - val_accuracy: 0.6911 - val_loss: 0.6397
# Epoch 3/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6986 - loss: 0.6441 - val_accuracy: 0.7480 - val_loss: 0.6018
# Epoch 4/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7373 - loss: 0.6044 - val_accuracy: 0.7642 - val_loss: 0.5635
# Epoch 5/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7373 - loss: 0.5649 - val_accuracy: 0.7886 - val_loss: 0.5240
# Epoch 6/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7475 - loss: 0.5274 - val_accuracy: 0.7805 - val_loss: 0.4897
# Epoch 7/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7617 - loss: 0.4985 - val_accuracy: 0.7724 - val_loss: 0.4663
# Epoch 8/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7678 - loss: 0.4781 - val_accuracy: 0.7642 - val_loss: 0.4508
# Epoch 9/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7780 - loss: 0.4655 - val_accuracy: 0.7805 - val_loss: 0.4430
# Epoch 10/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7902 - loss: 0.4552 - val_accuracy: 0.7805 - val_loss: 0.4356
# Epoch 11/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7800 - loss: 0.4519 - val_accuracy: 0.7886 - val_loss: 0.4311
# Epoch 12/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7902 - loss: 0.4416 - val_accuracy: 0.7886 - val_loss: 0.4313
# Epoch 13/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7841 - loss: 0.4373 - val_accuracy: 0.7886 - val_loss: 0.4242
# Epoch 14/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7862 - loss: 0.4334 - val_accuracy: 0.7886 - val_loss: 0.4272
# Epoch 15/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7984 - loss: 0.4287 - val_accuracy: 0.7967 - val_loss: 0.4254
# Epoch 16/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8024 - loss: 0.4262 - val_accuracy: 0.7967 - val_loss: 0.4219
# Epoch 17/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7943 - loss: 0.4238 - val_accuracy: 0.7967 - val_loss: 0.4228
# Epoch 18/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8045 - loss: 0.4216 - val_accuracy: 0.7886 - val_loss: 0.4249
# Epoch 19/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8086 - loss: 0.4188 - val_accuracy: 0.7805 - val_loss: 0.4218
# Epoch 20/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8065 - loss: 0.4162 - val_accuracy: 0.7967 - val_loss: 0.4249
# Epoch 21/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8086 - loss: 0.4135 - val_accuracy: 0.7967 - val_loss: 0.4262
# Epoch 22/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8045 - loss: 0.4122 - val_accuracy: 0.7967 - val_loss: 0.4236
# Epoch 23/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8106 - loss: 0.4103 - val_accuracy: 0.7886 - val_loss: 0.4251
# Epoch 24/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8147 - loss: 0.4075 - val_accuracy: 0.7886 - val_loss: 0.4264
# Epoch 25/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8106 - loss: 0.4058 - val_accuracy: 0.7886 - val_loss: 0.4228
# Epoch 26/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8147 - loss: 0.4045 - val_accuracy: 0.7967 - val_loss: 0.4269
# Epoch 27/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8147 - loss: 0.4024 - val_accuracy: 0.7886 - val_loss: 0.4259
# Epoch 28/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8167 - loss: 0.4014 - val_accuracy: 0.7967 - val_loss: 0.4280
# Epoch 29/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8147 - loss: 0.3986 - val_accuracy: 0.7886 - val_loss: 0.4309
# Epoch 29: early stopping
# Restoring model weights from the end of the best epoch: 19.

# %% [markdown]
# ### Subtask 3.5: Evaluating the Tuned, Regularized Model
# **Concept:** Compare the final test accuracy of the tuned, early-stopped model against the baseline model trained with fixed epochs in Task 1.

# %%
from sklearn.metrics import accuracy_score

# %%
# Evaluate baseline model from Task 1
baseline_accuracy = ann_pima.evaluate(X_test_p, y_test_p, verbose=0)[1]

# %%
# Evaluate the tuned, early-stopped model
tuned_accuracy = tuned_model.evaluate(X_test_p, y_test_p, verbose=0)[1]

# %%
comparison_df = pd.DataFrame({
    'Model Configuration': ['Baseline ANN (Fixed 50 Epochs)', 'Tuned ANN (with Early Stopping)'],
    'Test Accuracy (%)': [baseline_accuracy * 100, tuned_accuracy * 100],
    'Epochs Trained': [50, len(history_tuned.history['loss'])]
})

# %%
print("--- Final Performance Comparison ---")
print(comparison_df.to_string(index=False))
# Out:
# --- Final Performance Comparison ---
#             Model Configuration  Test Accuracy (%)  Epochs Trained
#  Baseline ANN (Fixed 50 Epochs)          73.376626              50
# Tuned ANN (with Early Stopping)          72.727275              29
